# %% [markdown]
# <a href="https://colab.research.google.com/github/mjay9/iUnderstand/blob/main/iUnderstand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with JioCare.txt', 'r', encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 6/5/21, 12:30 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 6/5/21, 12:30 - This chat is with the official business account of JioCare. Tap to learn more.
# 6/5/21, 12:30 - This chat is with the official business account of JioCare. Tap to learn more.
# 6/5/21, 12:30 - MJ: hi
# 6/5/21, 12:30 - JioCare: Hi, Welcome to JioCare.
#
# I am your Personal Jio Assistant and you are chatting for your Jio number +91933xxxxx94.
#
# Tap on the below button for Main Menu 👇
#
# Your selection would be considered as acceptance of our privacy policy mentioned on Jio.com. T&C apply. https://www.jio.com/en-in/privacy-policy.
#
# At any point in time, if you want to change language, type *'Set Language'* Covid Vaccine and Info Jio SIM Recharge New Jio SIM/Port-in(MNP) Support for Jio SIM Support for JioFiber Support for Intl Roaming Support for JioMart Change Chat Language
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern, data)[2:]
messages
# Out:
# ['This chat is with the official business account of JioCare. Tap to learn more.\n',
#  'This chat is with the official business account of JioCare. Tap to learn more.\n',
#  'MJ: hi\n',
#  "JioCare: Hi, Welcome to JioCare.\n\nI am your Personal Jio Assistant and you are chatting for your Jio number +91933xxxxx94.\n\nTap on the below button for Main Menu 👇\n\nYour selection would be considered as acceptance of our privacy policy mentioned on Jio.com. T&C apply. https://www.jio.com/en-in/privacy-policy.\n\nAt any point in time, if you want to change language, type *'Set Language'* Covid Vaccine and Info Jio SIM Recharge New Jio SIM/Port-in(MNP) Support for Jio SIM Support for JioFiber Support for Intl Roaming Support for JioMart Change Chat Language\n",
# ...

# %%
dates  = re.findall(pattern, data)
dates
# Out:
# ['6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:30 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:32 - ',
#  '6/5/21, 12:31 - ',
#  '6/5/21, 12:33 - ',
#  '6/5/21, 12:33 - ',
#  '9/6/21, 18:08 - ',
#  '10/29/21, 07:06 - ',
#  '11/1/21, 07:38 - ',
#  '11/1/21, 07:39 - ',
#  '11/7/21, 19:52 - ',
#  '11/8/21, 20:34 - ',
#  '11/10/21, 04:25 - ',
#  '11/28/21, 13:12 - ',
#  '1/10/22, 14:23 - ',
#  '4/11/22, 17:11 - ',
#  '10/31/22, 16:26 - ',
#  '10/31/22, 16:26 - ',
#  '10/31/22, 16:26 - ',
#  '10/31/22, 16:26 - ',
#  '10/31/22, 16:27 - ',
#  '10/31/22, 16:27 - ',
#  '10/31/22, 16:27 - ',
# ...
